# %%
import numpy as np

# %% [markdown]
# Standard Library -> Libraries available by default in any python installation
#
# Third Party Library -> Libraries we have to install separately from third party sources

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = [[1, 2], [3, 4]]
B = [[1, 1], [1, 1]]

print(A+B)
# Out:
# [[1, 2], [3, 4], [1, 1], [1, 1]]

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[1, 1], [1, 1]])

print(A.ndim)
print(A.shape)
print(A.size)
# Out:
# 2
# (2, 2)
# 4

# %%
type(A)
np.ndarray.ndim
# Out:
# <attribute 'ndim' of 'numpy.ndarray' objects>

# %%
type(A).ndim
# Out:
# <attribute 'ndim' of 'numpy.ndarray' objects>

# %%
from numpy.linalg import inv

# %%
A = np.array([[1, 2], [3, 4]])
A_inv = inv(A)

print(A)
print(A_inv)
# Out:
# [[1 2]
#  [3 4]]
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %% [markdown]
# Data Analysis and Processing -> Pandas
#
# Machine Learning Models -> Scikit-Learn
#
# Deep Learning -> Tensorflow / PyTorch
